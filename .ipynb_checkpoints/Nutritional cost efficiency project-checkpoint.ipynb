# %% [markdown]
# # Nutritional cost efficiency
# As someone of a tall stature and an interest in working out, efficient nutrition is a major factor in my personal life. This means that, at the best of times, my food expenses can be significant; especially when trying to restrict myself to healthy food.
#
# The recent(2022) inflation crisis has made it an even more pressing issue, which lead me to the following project idea: Analyse which foods are most cost efficient in regards to their macronutrients and price per 100g.
#
# ## Overview of steps
# * First, I will detail here how I scrape the Albert Heijn website for data on food, price and macronutrients(macro's).
# * Second, I will proceed to import, clean and engineer the data through regex functions and the pandas library.
# * Third, I will analyze the data, visualize it and find the most cost efficient foodstuffs to base my personal shopping list on.
#
# ## Step 1: The scraping
# As a scraping tool, I use the `webscraper.io` chrome extension, for its ease of use and efficiency. In the future, I intend to learn to use scrapy and selenium as well.
# The target website will be `ah.nl` because it is the only website that offers product prices as well as their nutritional scores.
#
# The steps of the scraping are as follows:
# * I navigate to the website I want to scrape
# * I explore the website to get an idea of the general structure. I see that I will need to scrape a list of products, entering each item's page in the list to get the nutritional information, then returning to the list.
# * Through exploring the Albert Heijn website and its quirks, I found the most efficient way to iterate through the products is to use the link selector as a parent selector and then to use text selectors for the various attributes I need. I do this for each category of product individually, since this seems to be easiest for this particular website.
# * I export the data as a `.csv` file
#
# ### Test: fruits and vegetables
# Having scraped the first section of data, fruits and vegetables, I examine the data to see if I can effectively clean and wrangle it. If this is successful, I can proceed to perform the same steps on the rest of the data, append it to each other, and live happily ever after with a nice, useful dataset.
#
# I start by importing the pandas and regex libraries, then uploading the vegetable data and looking at the info.

# %%
import pandas as pd
import re

veggies = pd.read_csv('albertHeijn-veg-data.csv')

veggies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 972 entries, 0 to 971
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   web-scraper-order            972 non-null    object
#  1   web-scraper-start-url        972 non-null    object
#  2   link-selector                972 non-null    object
#  3   link-selector-href           972 non-null    object
#  4   product-base-price-selector  971 non-null    float64
#  5   product-calorie-selector     871 non-null    object
#  6   product-fat-selector         871 non-null    object
#  7   product-carb-selector        871 non-null    object
#  8   product-price-kilo-selector  442 non-null    object
#  9   product-protein-selector     871 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 76.1+ KB

# %% [markdown]
# Everything is as expected. I can start te cleaning process immediately, since I know the contents of the dataset relatively well.
#
# I'll start by removing all things that have null in the column of `price-kilo-selector`. Since the goal of the data is to find out which food is most cost efficient *per 100g*, this cannot be done unless there is a price/weight column. Without this, the data is only clutter.

# %%
veggies = veggies.dropna(subset = ['product-price-kilo-selector'])
veggies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442 entries, 0 to 531
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   web-scraper-order            442 non-null    object
#  1   web-scraper-start-url        442 non-null    object
#  2   link-selector                442 non-null    object
#  3   link-selector-href           442 non-null    object
#  4   product-base-price-selector  442 non-null    float64
#  5   product-calorie-selector     432 non-null    object
#  6   product-fat-selector         432 non-null    object
#  7   product-carb-selector        432 non-null    object
#  8   product-price-kilo-selector  442 non-null    object
#  9   product-protein-selector     432 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 38.0+ KB

# %% [markdown]
# Seeing that protein now has the most null values, I examine this column to find out more.

# %%
veggies[veggies['product-protein-selector'].isna()]
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 21      1665082182-22  https://www.ah.nl/producten/aardappel-groente-...
# 72      1665082304-73  https://www.ah.nl/producten/aardappel-groente-...
# 78      1665082318-79  https://www.ah.nl/producten/aardappel-groente-...
# 106    1665082386-107  https://www.ah.nl/producten/aardappel-groente-...
# 256    1665082764-257  https://www.ah.nl/producten/aardappel-groente-...
# 330    1665082964-331  https://www.ah.nl/producten/aardappel-groente-...
# 372    1665083072-373  https://www.ah.nl/producten/aardappel-groente-...
# 471    1665083318-472  https://www.ah.nl/producten/aardappel-groente-...
# 492    1665083371-493  https://www.ah.nl/producten/aardappel-groente-...
# 526    1665083453-527  https://www.ah.nl/producten/aardappel-groente-...
#
#                                 link-selector  \
# 21                   Verstegen Knoflookpoeder
# 72                         Drogheria Knoflook
# 78                  AH Luxe wokgroente Japans
# 106  AH Stoommaaltijd tortellini formaggio XL
# 256                 Verstegen Knoflook poeder
# 330                    AH Biologisch Zuurkool
# 372   AH Smoothie magnesium rood fruit bessen
# 471     Appels van het seizoen voordeelpakket
# 492           AH Vers sap ananas meloen mango
# 526                         Kanzi Appelen zak
#
#                                     link-selector-href  \
# 21   https://www.ah.nl/producten/product/wi414965/v...
# 72   https://www.ah.nl/producten/product/wi65767/dr...
# 78   https://www.ah.nl/producten/product/wi525249/a...
# 106  https://www.ah.nl/producten/product/wi531273/a...
# 256  https://www.ah.nl/producten/product/wi216639/v...
# 330  https://www.ah.nl/producten/product/wi525272/a...
# 372  https://www.ah.nl/producten/product/wi440502/a...
# 471  https://www.ah.nl/producten/product/wi234268/a...
# 492  https://www.ah.nl/producten/product/wi67839/ah...
# 526  https://www.ah.nl/producten/product/wi447162/k...
#
#      product-base-price-selector product-calorie-selector  \
# 21                          1.69                      NaN
# 72                          2.79                      NaN
# 78                          3.49                      NaN
# 106                         4.89                      NaN
# 256                         2.89                      NaN
# 330                         1.49                      NaN
# 372                         0.99                      NaN
# 471                         5.99                      NaN
# 492                         2.29                      NaN
# 526                         3.49                      NaN
#
#     product-fat-selector product-carb-selector   product-price-kilo-selector  \
# 21                   NaN                   NaN          Prijs per KG € 37,56
# 72                   NaN                   NaN          Prijs per KG € 55,80
# 78                   NaN                   NaN           Prijs per KG € 8,73
# 106                  NaN                   NaN  Normale prijs per KG € 11,33
# 256                  NaN                   NaN          Prijs per KG € 57,80
# 330                  NaN                   NaN           Prijs per KG € 2,98
# 372                  NaN                   NaN           Prijs per LT € 3,96
# 471                  NaN                   NaN           Prijs per KG € 2,00
# 492                  NaN                   NaN           Prijs per LT € 4,58
# 526                  NaN                   NaN           Prijs per KG € 3,49
#
#     product-protein-selector
# 21                       NaN
# 72                       NaN
# 78                       NaN
# 106                      NaN
# 256                      NaN
# 330                      NaN
# 372                      NaN
# 471                      NaN
# 492                      NaN
# 526                      NaN

# %% [markdown]
# The returned rows give several insights:
# * most of the products that have no protein also have no other nutritional data either
# * navigating to the page of the product, I find that it does mention protein content, but it is very small.
#
# ### Cleaning functions
#
# Now I will clean the data and make it useable, primarily using regex functions on each column, starting with the kcal per 100g row.
# The easiest way to do this is to define a function, which I can subsequently apply on the column as a whole. I start by defining a function that finds text in the pattern of `(digits)+'Kcal')`, but only gives me the digits part.

# %%
def calorie_grabber(text):
    if type(text) != str:
        return None
    calories = re.findall(r'(\d+) kcal', text)
    return float(calories[0])

# %% [markdown]
# Now the function is defined, I apply it to the original `product-calorie-selector` column and produce a new, clean column labeled `Kcal/100g`.

# %%
veggies['Kcal/100g'] = veggies['product-calorie-selector'].apply(calorie_grabber)
veggies
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0        1665082128-1  https://www.ah.nl/producten/aardappel-groente-...
# 2        1665082133-3  https://www.ah.nl/producten/aardappel-groente-...
# 3        1665082136-4  https://www.ah.nl/producten/aardappel-groente-...
# 4        1665082139-5  https://www.ah.nl/producten/aardappel-groente-...
# 5        1665082142-6  https://www.ah.nl/producten/aardappel-groente-...
# ..                ...                                                ...
# 527    1665083455-528  https://www.ah.nl/producten/aardappel-groente-...
# 528    1665083458-529  https://www.ah.nl/producten/aardappel-groente-...
# 529    1665083460-530  https://www.ah.nl/producten/aardappel-groente-...
# 530    1665083463-531  https://www.ah.nl/producten/aardappel-groente-...
# 531    1665083465-532  https://www.ah.nl/producten/aardappel-groente-...
#
#                                      link-selector  \
# 0                           AH Primeur aardappelen
# 2                    AH Vegan zeewiersalade wakame
# 3    Appelsientje Proef! sinaasappel mango kurkuma
# 4                           AH Paddenstoelengehakt
# 5                  AH Lunchsalade couscous falafel
# ..                                             ...
# 527        Bonduelle Gebroken sperzieboontjes fijn
# 528                            AH Bloemkoolroosjes
# 529                       AH Biologisch Boerenkool
# 530                    AH Partjes mandarijn op sap
# 531                              AH Zachte pruimen
#
#                                     link-selector-href  \
# 0    https://www.ah.nl/producten/product/wi96048/ah...
# 2    https://www.ah.nl/producten/product/wi523411/a...
# 3    https://www.ah.nl/producten/product/wi520760/a...
# 4    https://www.ah.nl/producten/product/wi515448/a...
# 5    https://www.ah.nl/producten/product/wi475648/a...
# ..                                                 ...
# 527  https://www.ah.nl/producten/product/wi216289/b...
# 528  https://www.ah.nl/producten/product/wi395953/a...
# 529  https://www.ah.nl/producten/product/wi135521/a...
# 530  https://www.ah.nl/producten/product/wi852/ah-p...
# 531  https://www.ah.nl/producten/product/wi396925/a...
#
#      product-base-price-selector product-calorie-selector  \
# 0                           2.99         371 kJ (88 kcal)
# 2                           2.39        439 kJ (105 kcal)
# 3                           1.89         173 kJ (41 kcal)
# 4                           2.49         124 kJ (29 kcal)
# 5                           3.79        610 kJ (147 kcal)
# ..                           ...                      ...
# 527                         0.89         121 kJ (29 kcal)
# 528                         2.29         108 kJ (26 kcal)
# 529                         2.69         138 kJ (33 kcal)
# 530                         1.65         185 kJ (44 kcal)
# 531                         2.09       1075 kJ (255 kcal)
#
#     product-fat-selector product-carb-selector  product-price-kilo-selector  \
# 0                 Vet0 g      Koolhydraten19 g          Prijs per KG € 1,99
# 2               Vet5.2 g      Koolhydraten11 g         Prijs per KG € 23,90
# 3                 Vet0 g     Koolhydraten9.6 g  Normale prijs per LT € 1,89
# 4               Vet0.1 g     Koolhydraten4.3 g          Prijs per KG € 8,30
# 5               Vet9.6 g      Koolhydraten10 g         Prijs per KG € 12,43
# ..                   ...                   ...                          ...
# 527             Vet0.4 g     Koolhydraten3.8 g          Prijs per KG € 8,09
# 528             Vet0.2 g       Koolhydraten3 g          Prijs per KG € 5,73
# 529             Vet0.6 g     Koolhydraten1.6 g         Prijs per KG € 17,93
# 530               Vet0 g     Koolhydraten9.6 g          Prijs per KG € 9,43
# 531             Vet0.4 g      Koolhydraten57 g          Prijs per KG € 8,36
#
#     product-protein-selector  Kcal/100g
# 0                Eiwitten2 g       88.0
# 2              Eiwitten1.5 g      105.0
# 3              Eiwitten0.2 g       41.0
# 4              Eiwitten2.5 g       29.0
# 5              Eiwitten3.7 g      147.0
# ..                       ...        ...
# 527            Eiwitten1.6 g       29.0
# 528            Eiwitten1.9 g       26.0
# 529              Eiwitten3 g       33.0
# 530            Eiwitten0.8 g       44.0
# 531              Eiwitten2 g      255.0
#
# [442 rows x 11 columns]

# %% [markdown]
# Seeing the function has succesfully been applied to this column, I can use the exact same principle to the other columns. I make some minor alterations to the function to allow the function to parse this particular format of text, but generally it can remain as it is.

# %%
def value_grabber(text):
    if type(text) != str:
        return None
    value1 = re.findall(r'(\d+\.?\d+?) g', text)
    if len(value1) < 1:
        return None
    return float(value1[0])

# %% [markdown]
# Having formulated the function to properly parse the text in these columns, I can apply it to all three columns individually and create the proper clean columns `fat/100g`, `carbs/100g`, `protein/100g`.

# %%
veggies['fat/100g'] = veggies['product-fat-selector'].apply(value_grabber)
veggies['carb/100g'] = veggies['product-carb-selector'].apply(value_grabber)
veggies['protein/100g'] = veggies['product-protein-selector'].apply(value_grabber)
veggies
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0        1665082128-1  https://www.ah.nl/producten/aardappel-groente-...
# 2        1665082133-3  https://www.ah.nl/producten/aardappel-groente-...
# 3        1665082136-4  https://www.ah.nl/producten/aardappel-groente-...
# 4        1665082139-5  https://www.ah.nl/producten/aardappel-groente-...
# 5        1665082142-6  https://www.ah.nl/producten/aardappel-groente-...
# ..                ...                                                ...
# 527    1665083455-528  https://www.ah.nl/producten/aardappel-groente-...
# 528    1665083458-529  https://www.ah.nl/producten/aardappel-groente-...
# 529    1665083460-530  https://www.ah.nl/producten/aardappel-groente-...
# 530    1665083463-531  https://www.ah.nl/producten/aardappel-groente-...
# 531    1665083465-532  https://www.ah.nl/producten/aardappel-groente-...
#
#                                      link-selector  \
# 0                           AH Primeur aardappelen
# 2                    AH Vegan zeewiersalade wakame
# 3    Appelsientje Proef! sinaasappel mango kurkuma
# 4                           AH Paddenstoelengehakt
# 5                  AH Lunchsalade couscous falafel
# ..                                             ...
# 527        Bonduelle Gebroken sperzieboontjes fijn
# 528                            AH Bloemkoolroosjes
# 529                       AH Biologisch Boerenkool
# 530                    AH Partjes mandarijn op sap
# 531                              AH Zachte pruimen
#
#                                     link-selector-href  \
# 0    https://www.ah.nl/producten/product/wi96048/ah...
# 2    https://www.ah.nl/producten/product/wi523411/a...
# 3    https://www.ah.nl/producten/product/wi520760/a...
# 4    https://www.ah.nl/producten/product/wi515448/a...
# 5    https://www.ah.nl/producten/product/wi475648/a...
# ..                                                 ...
# 527  https://www.ah.nl/producten/product/wi216289/b...
# 528  https://www.ah.nl/producten/product/wi395953/a...
# 529  https://www.ah.nl/producten/product/wi135521/a...
# 530  https://www.ah.nl/producten/product/wi852/ah-p...
# 531  https://www.ah.nl/producten/product/wi396925/a...
#
#      product-base-price-selector product-calorie-selector  \
# 0                           2.99         371 kJ (88 kcal)
# 2                           2.39        439 kJ (105 kcal)
# 3                           1.89         173 kJ (41 kcal)
# 4                           2.49         124 kJ (29 kcal)
# 5                           3.79        610 kJ (147 kcal)
# ..                           ...                      ...
# 527                         0.89         121 kJ (29 kcal)
# 528                         2.29         108 kJ (26 kcal)
# 529                         2.69         138 kJ (33 kcal)
# 530                         1.65         185 kJ (44 kcal)
# 531                         2.09       1075 kJ (255 kcal)
#
#     product-fat-selector product-carb-selector  product-price-kilo-selector  \
# 0                 Vet0 g      Koolhydraten19 g          Prijs per KG € 1,99
# 2               Vet5.2 g      Koolhydraten11 g         Prijs per KG € 23,90
# 3                 Vet0 g     Koolhydraten9.6 g  Normale prijs per LT € 1,89
# 4               Vet0.1 g     Koolhydraten4.3 g          Prijs per KG € 8,30
# 5               Vet9.6 g      Koolhydraten10 g         Prijs per KG € 12,43
# ..                   ...                   ...                          ...
# 527             Vet0.4 g     Koolhydraten3.8 g          Prijs per KG € 8,09
# 528             Vet0.2 g       Koolhydraten3 g          Prijs per KG € 5,73
# 529             Vet0.6 g     Koolhydraten1.6 g         Prijs per KG € 17,93
# 530               Vet0 g     Koolhydraten9.6 g          Prijs per KG € 9,43
# 531             Vet0.4 g      Koolhydraten57 g          Prijs per KG € 8,36
#
#     product-protein-selector  Kcal/100g  fat/100g  carb/100g  protein/100g
# 0                Eiwitten2 g       88.0       NaN       19.0           NaN
# 2              Eiwitten1.5 g      105.0       5.2       11.0           1.5
# 3              Eiwitten0.2 g       41.0       NaN        9.6           0.2
# 4              Eiwitten2.5 g       29.0       0.1        4.3           2.5
# 5              Eiwitten3.7 g      147.0       9.6       10.0           3.7
# ..                       ...        ...       ...        ...           ...
# 527            Eiwitten1.6 g       29.0       0.4        3.8           1.6
# 528            Eiwitten1.9 g       26.0       0.2        NaN           1.9
# 529              Eiwitten3 g       33.0       0.6        1.6           NaN
# 530            Eiwitten0.8 g       44.0       NaN        9.6           0.8
# 531              Eiwitten2 g      255.0       0.4       57.0           NaN
#
# [442 rows x 14 columns]

# %% [markdown]
# I move on to clean `product-price-kilo-selector`. To do this, I'm going to have to replace the `,` with a `.`, and divide the total by 10 so I can immediately see the price per 100g/ml.

# %%
def price_in_100gram_grabber(text):
    if type(text[0]) != str:
        return None
    cleanprice = text.replace(",",".")
    price = re.findall(r'K?G?L?T? € (\d+\.?\d+?)', cleanprice)
    if len(price) < 1:
        return None
    pricefloat = float(price[0]) 
    return pricefloat/10

# %%
price_in_100gram_grabber('KG € 12,99')
# Out:
# 1.29

# %%
veggies['€/100g or ml'] = veggies['product-price-kilo-selector'].apply(price_in_100gram_grabber)
veggies
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0        1665082128-1  https://www.ah.nl/producten/aardappel-groente-...
# 2        1665082133-3  https://www.ah.nl/producten/aardappel-groente-...
# 3        1665082136-4  https://www.ah.nl/producten/aardappel-groente-...
# 4        1665082139-5  https://www.ah.nl/producten/aardappel-groente-...
# 5        1665082142-6  https://www.ah.nl/producten/aardappel-groente-...
# ..                ...                                                ...
# 527    1665083455-528  https://www.ah.nl/producten/aardappel-groente-...
# 528    1665083458-529  https://www.ah.nl/producten/aardappel-groente-...
# 529    1665083460-530  https://www.ah.nl/producten/aardappel-groente-...
# 530    1665083463-531  https://www.ah.nl/producten/aardappel-groente-...
# 531    1665083465-532  https://www.ah.nl/producten/aardappel-groente-...
#
#                                      link-selector  \
# 0                           AH Primeur aardappelen
# 2                    AH Vegan zeewiersalade wakame
# 3    Appelsientje Proef! sinaasappel mango kurkuma
# 4                           AH Paddenstoelengehakt
# 5                  AH Lunchsalade couscous falafel
# ..                                             ...
# 527        Bonduelle Gebroken sperzieboontjes fijn
# 528                            AH Bloemkoolroosjes
# 529                       AH Biologisch Boerenkool
# 530                    AH Partjes mandarijn op sap
# 531                              AH Zachte pruimen
#
#                                     link-selector-href  \
# 0    https://www.ah.nl/producten/product/wi96048/ah...
# 2    https://www.ah.nl/producten/product/wi523411/a...
# 3    https://www.ah.nl/producten/product/wi520760/a...
# 4    https://www.ah.nl/producten/product/wi515448/a...
# 5    https://www.ah.nl/producten/product/wi475648/a...
# ..                                                 ...
# 527  https://www.ah.nl/producten/product/wi216289/b...
# 528  https://www.ah.nl/producten/product/wi395953/a...
# 529  https://www.ah.nl/producten/product/wi135521/a...
# 530  https://www.ah.nl/producten/product/wi852/ah-p...
# 531  https://www.ah.nl/producten/product/wi396925/a...
#
#      product-base-price-selector product-calorie-selector  \
# 0                           2.99         371 kJ (88 kcal)
# 2                           2.39        439 kJ (105 kcal)
# 3                           1.89         173 kJ (41 kcal)
# 4                           2.49         124 kJ (29 kcal)
# 5                           3.79        610 kJ (147 kcal)
# ..                           ...                      ...
# 527                         0.89         121 kJ (29 kcal)
# 528                         2.29         108 kJ (26 kcal)
# 529                         2.69         138 kJ (33 kcal)
# 530                         1.65         185 kJ (44 kcal)
# 531                         2.09       1075 kJ (255 kcal)
#
#     product-fat-selector product-carb-selector  product-price-kilo-selector  \
# 0                 Vet0 g      Koolhydraten19 g          Prijs per KG € 1,99
# 2               Vet5.2 g      Koolhydraten11 g         Prijs per KG € 23,90
# 3                 Vet0 g     Koolhydraten9.6 g  Normale prijs per LT € 1,89
# 4               Vet0.1 g     Koolhydraten4.3 g          Prijs per KG € 8,30
# 5               Vet9.6 g      Koolhydraten10 g         Prijs per KG € 12,43
# ..                   ...                   ...                          ...
# 527             Vet0.4 g     Koolhydraten3.8 g          Prijs per KG € 8,09
# 528             Vet0.2 g       Koolhydraten3 g          Prijs per KG € 5,73
# 529             Vet0.6 g     Koolhydraten1.6 g         Prijs per KG € 17,93
# 530               Vet0 g     Koolhydraten9.6 g          Prijs per KG € 9,43
# 531             Vet0.4 g      Koolhydraten57 g          Prijs per KG € 8,36
#
#     product-protein-selector  Kcal/100g  fat/100g  carb/100g  protein/100g  \
# 0                Eiwitten2 g       88.0       NaN       19.0           NaN
# 2              Eiwitten1.5 g      105.0       5.2       11.0           1.5
# 3              Eiwitten0.2 g       41.0       NaN        9.6           0.2
# 4              Eiwitten2.5 g       29.0       0.1        4.3           2.5
# 5              Eiwitten3.7 g      147.0       9.6       10.0           3.7
# ..                       ...        ...       ...        ...           ...
# 527            Eiwitten1.6 g       29.0       0.4        3.8           1.6
# 528            Eiwitten1.9 g       26.0       0.2        NaN           1.9
# 529              Eiwitten3 g       33.0       0.6        1.6           NaN
# 530            Eiwitten0.8 g       44.0       NaN        9.6           0.8
# 531              Eiwitten2 g      255.0       0.4       57.0           NaN
#
#      €/100g or ml
# 0            0.19
# 2            2.39
# 3            0.18
# 4            0.83
# 5            1.24
# ..            ...
# 527          0.80
# 528          0.57
# 529          1.79
# 530          0.94
# 531          0.83
#
# [442 rows x 15 columns]

# %%
veggies_clean = veggies[['link-selector','product-base-price-selector','Kcal/100g', 'fat/100g', 'carb/100g','protein/100g', '€/100g or ml']]
veggies_clean
# Out:
#                                      link-selector  \
# 0                           AH Primeur aardappelen
# 2                    AH Vegan zeewiersalade wakame
# 3    Appelsientje Proef! sinaasappel mango kurkuma
# 4                           AH Paddenstoelengehakt
# 5                  AH Lunchsalade couscous falafel
# ..                                             ...
# 527        Bonduelle Gebroken sperzieboontjes fijn
# 528                            AH Bloemkoolroosjes
# 529                       AH Biologisch Boerenkool
# 530                    AH Partjes mandarijn op sap
# 531                              AH Zachte pruimen
#
#      product-base-price-selector  Kcal/100g  fat/100g  carb/100g  \
# 0                           2.99       88.0       NaN       19.0
# 2                           2.39      105.0       5.2       11.0
# 3                           1.89       41.0       NaN        9.6
# 4                           2.49       29.0       0.1        4.3
# 5                           3.79      147.0       9.6       10.0
# ..                           ...        ...       ...        ...
# 527                         0.89       29.0       0.4        3.8
# 528                         2.29       26.0       0.2        NaN
# 529                         2.69       33.0       0.6        1.6
# 530                         1.65       44.0       NaN        9.6
# 531                         2.09      255.0       0.4       57.0
#
#      protein/100g  €/100g or ml
# 0             NaN          0.19
# 2             1.5          2.39
# 3             0.2          0.18
# 4             2.5          0.83
# 5             3.7          1.24
# ..            ...           ...
# 527           1.6          0.80
# 528           1.9          0.57
# 529           NaN          1.79
# 530           0.8          0.94
# 531           NaN          0.83
#
# [442 rows x 7 columns]

# %%
import seaborn as sns

sns.lineplot(data=veggies_clean, x= 'protein/100g', y='€/100g or ml' )
# Out:
# <AxesSubplot:xlabel='protein/100g', ylabel='€/100g or ml'>

# %%
veggies_clean[veggies_clean['protein/100g']>7]
# Out:
#                                  link-selector  product-base-price-selector  \
# 6                   AH Biologisch Popcorn mais                         1.99
# 8             AH Biologisch Fruit & pitten mix                         3.29
# 19                    AH Biologisch Gojibessen                         5.19
# 37          AH Biologisch Oranje linzen kiemen                         1.99
# 38                    Moonpop Veggiez sea salt                         1.99
# 69                       AH Biologisch Kurkuma                         1.49
# 101                            Hak Kidneybonen                         1.99
# 108        Bonduelle Rode kidneybonen 2 mini's                         1.99
# 109                             AH Onion rings                         1.15
# 120                           Hak Kikkererwten                         2.35
# 131             No Fairytales Tomaten tortilla                         2.69
# 159               Snaqs Seaweed Crisps Seasalt                         2.49
# 165                Valle del sole Popcorn mais                         1.99
# 179     AH Gesneden verspakket mexicaanse wrap                         5.99
# 182  AH Gesneden verspakket Griekse pita gyros                         5.99
# 253             Bonduelle Rode kidneybonen bio                         2.49
# 282                 Magioni Paprika pizzabodem                         3.99
# 293               PROPER Barbecue lentil chips                         2.29
# 297           Bonduelle Rode kidneybonen - bio                         1.69
# 300                            Hak Witte bonen                         1.99
# 303                  Snaqs Fried Vegetable Mix                         2.79
# 310                   AH Pastasalade kip bacon                         3.89
# 395                  AH Lunchsalade kip Caesar                         3.59
# 405        AH Gesneden verspakket ovensch knol                         4.49
# 412                 Bonduelle Rode kidneybonen                         1.55
# 414                Hak Kleine rode kidneybonen                         2.19
# 433                           Hak Zwarte bonen                         1.99
# 448                           Hak Kikkererwten                         2.19
# 460                            AH Zwarte bonen                         1.29
# 476               PROPER Sea salt lentil chips                         2.29
# 493                  Knorr Veggie wraps bieten                         2.75
# 498                               AH Sojabonen                         2.49
# 509                 Bonduelle Edamame boontjes                         2.49
#
#      Kcal/100g  fat/100g  carb/100g  protein/100g  €/100g or ml
# 6        374.0       NaN       71.0          11.0          0.39
# 8        440.0      20.0       53.0           8.9          1.09
# 19       295.0       3.5       43.0          13.0          2.96
# 37       172.0       0.6       28.0          12.0          1.32
# 38       396.0       9.6       63.3           9.3          2.34
# 69       338.0       9.9       44.0           7.8          1.86
# 101      114.0       0.7       13.9           8.3          0.82
# 108      108.0       0.6       13.9           7.7          1.65
# 109      524.0      29.0       57.0           7.5          0.92
# 120      138.0       NaN       15.9           7.6          1.09
# 131      250.0       4.2       43.1           9.3          1.34
# 159      384.0       7.1       68.4          10.9          6.22
# 165      374.0       NaN       71.0          11.0          0.22
# 179      138.0       3.2       17.0           9.1          0.64
# 182      135.0       5.3       11.0           9.4          0.75
# 253      111.0       0.7       13.8           8.7          0.99
# 282      222.0       2.4       42.0           7.1          1.02
# 293      469.0      19.4       63.6           9.5          2.69
# 297      111.0       0.7       13.8           8.7          1.35
# 300      113.0       NaN       13.4           7.8          0.78
# 303      373.0       9.5       55.0           7.9          3.72
# 310      173.0       9.1       15.0           7.3          1.11
# 395      148.0       8.3        NaN          11.0          1.59
# 405      113.0       5.6        7.3           7.4          0.59
# 412      108.0       0.6       13.9           7.7          0.62
# 414      101.0      10.5       12.6           7.6          1.09
# 433      140.0      10.5       22.8           8.1          0.99
# 448      134.0      11.5       19.9           8.3          1.09
# 460      105.0       0.6       15.0           7.1          0.32
# 476      482.0      20.8       63.6           9.7          2.69
# 493      306.0       5.4       52.0           9.9          0.74
# 498      107.0       4.7        3.8          10.0          1.66
# 509      135.0       6.6        2.8          13.0          0.83
