# %% [markdown]
# # Nutritional cost efficiency
# As someone of a tall stature and an interest in working out, efficient nutrition is a major factor in my personal life. This means that, at the best of times, my food expenses can be significant; especially when trying to restrict myself to healthy food.
#
# The recent(2022) inflation crisis has made it an even more pressing issue, which lead me to the following project idea: Collect a set of data from which one can derive the prices as well as the nutritional value of different products. I haven't been able to find a repository with such data easily navigable anywhere online.
#
# So why not make one?
#
# ## Overview of steps
# * First, I will detail here how I scrape the Albert Heijn website for data on food, price and macronutrients(macro's).
# * Second, I will proceed to import, clean and engineer the data through regex functions and the pandas library.
#
# ## Step 1: The scraping
# As a scraping tool, I use the `webscraper.io` chrome extension, for its ease of use and efficiency. In the future, I intend to learn to use scrapy and selenium as well.
# The target website will be `ah.nl` because it is the only website that offers product prices as well as their nutritional scores.
#
# The steps of the scraping are as follows:
# * I navigate to the website I want to scrape
# * I explore the website to get an idea of the general structure. I see that I will need to scrape a list of products, entering each item's page in the list to get the nutritional information, then returning to the list.
# * Through exploring the Albert Heijn website and its quirks, I found the most efficient way to iterate through the products is to use the link selector as a parent selector and then to use text selectors for the various attributes I need. I do this for each category of product individually, since this seems to be easiest for this particular website.
# * This way, it also becomes easy for me to add or remove categories of products from the final dataset, simply by removing or adding files to the initial merging of the data.
# * I export the data as a `.csv` file
#
# ###  Importing and merging the data
# Having scraped the sections of data separately, I examine the data to see if I can effectively clean and wrangle it.
#
# I start by importing the pandas and regex libraries, then uploading the various datasets, examining and looking at the info.

# %%
import pandas as pd
import re

set1 = pd.read_csv('albertHeijn-veg-data.csv')
set2 = pd.read_csv('albertHeijn-meat-data.csv')
set3 = pd.read_csv('albertHeijn-meal-data.csv')
set4 = pd.read_csv('albertHeijn-dairy-data.csv')
set5 = pd.read_csv('albertHeijn-cheese-data.csv')
set6 = pd.read_csv('albertHeijn-breakfast-data1.csv')
set7 = pd.read_csv('albertHeijn-breakfast-data2.csv')
set8 = pd.read_csv('albertHeijn-bakery-data.csv')
set9 = pd.read_csv('albertHeijn-snack1-data.csv')
set10 = pd.read_csv('albertHeijn-snack2-data.csv')
set11 = pd.read_csv('albertHeijn-snack3-data.csv')
set12 = pd.read_csv('albertHeijn-snack4-data.csv')
# set13 = pd.read_csv('albertHeijn-bakery-data.csv')

productset = [set1,
              set2,
              set3,
              set4,
              set5,
              set6,
              set7,
              set8,
                set9,
                set10,
                set11,
                set12,
#                set13
             ]

products = pd.concat(productset, ignore_index=True)

# %% [markdown]
# Having imported and merged the data, I start the proces by removing the duplicates that will have snuck in by being featured in multiple categories on the source website.

# %%
products = products.drop_duplicates(subset='link-selector')
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6479 entries, 0 to 10784
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   web-scraper-order            6479 non-null   object
#  1   web-scraper-start-url        6479 non-null   object
#  2   link-selector                6478 non-null   object
#  3   link-selector-href           6478 non-null   object
#  4   product-base-price-selector  6477 non-null   float64
#  5   product-calorie-selector     6159 non-null   object
#  6   product-fat-selector         6153 non-null   object
#  7   product-carb-selector        6158 non-null   object
#  8   product-price-kilo-selector  5337 non-null   object
#  9   product-protein-selector     6159 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 556.8+ KB

# %% [markdown]
# Everything is as expected. I can start te cleaning process immediately, since I know the contents of the dataset relatively well.
#
# I'll start by removing all things that have null in the column of `price-kilo-selector`. Since the goal of the data is to find out which food is most cost efficient *per 100g*, this cannot be done unless there is a price/weight column. Without this, the data is only clutter.

# %%
products = products.dropna(subset = ['product-price-kilo-selector'])

products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5337 entries, 0 to 10784
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   web-scraper-order            5337 non-null   object
#  1   web-scraper-start-url        5337 non-null   object
#  2   link-selector                5337 non-null   object
#  3   link-selector-href           5337 non-null   object
#  4   product-base-price-selector  5337 non-null   float64
#  5   product-calorie-selector     5278 non-null   object
#  6   product-fat-selector         5272 non-null   object
#  7   product-carb-selector        5277 non-null   object
#  8   product-price-kilo-selector  5337 non-null   object
#  9   product-protein-selector     5278 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 458.6+ KB

# %% [markdown]
# Seeing that protein now has the most null values, I examine this column to find out more.

# %%
products[products['product-protein-selector'].isna()]
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 21       1665082182-22  https://www.ah.nl/producten/aardappel-groente-...
# 72       1665082304-73  https://www.ah.nl/producten/aardappel-groente-...
# 78       1665082318-79  https://www.ah.nl/producten/aardappel-groente-...
# 106     1665082386-107  https://www.ah.nl/producten/aardappel-groente-...
# 256     1665082764-257  https://www.ah.nl/producten/aardappel-groente-...
# 330     1665082964-331  https://www.ah.nl/producten/aardappel-groente-...
# 372     1665083072-373  https://www.ah.nl/producten/aardappel-groente-...
# 471     1665083318-472  https://www.ah.nl/producten/aardappel-groente-...
# 492     1665083371-493  https://www.ah.nl/producten/aardappel-groente-...
# 526     1665083453-527  https://www.ah.nl/producten/aardappel-groente-...
# 1312    1665118564-455  https://www.ah.nl/producten/vlees-kip-vis-vega...
# 1388    1665118739-531  https://www.ah.nl/producten/vlees-kip-vis-vega...
# 1487    1665118966-630  https://www.ah.nl/producten/vlees-kip-vis-vega...
# 1607    1665119245-750  https://www.ah.nl/producten/vlees-kip-vis-vega...
# 1641    1665119324-784  https://www.ah.nl/producten/vlees-kip-vis-vega...
# 1818    1665119739-961  https://www.ah.nl/producten/vlees-kip-vis-vega...
# 2036    1665090621-158  https://www.ah.nl/producten/salades-pizza-maal...
# 2117    1665090817-239  https://www.ah.nl/producten/salades-pizza-maal...
# 2145    1665090884-267  https://www.ah.nl/producten/salades-pizza-maal...
# 2147    1665090889-269  https://www.ah.nl/producten/salades-pizza-maal...
# 2150    1665090896-272  https://www.ah.nl/producten/salades-pizza-maal...
# 2445    1665091617-567  https://www.ah.nl/producten/salades-pizza-maal...
# 2592     1665125704-51  https://www.ah.nl/producten/zuivel-plantaardig...
# 2724    1665126019-183  https://www.ah.nl/producten/zuivel-plantaardig...
# 2775    1665126144-234  https://www.ah.nl/producten/zuivel-plantaardig...
# 2887    1665126414-346  https://www.ah.nl/producten/zuivel-plantaardig...
# 3550     1665121894-33  https://www.ah.nl/producten/kaas-vleeswaren-ta...
# 2724                         1.04                      NaN
# 2775                         1.59                      NaN
# 2887                         5.69                      NaN
# 3550                         3.19                      NaN
# 3692                         2.99                      NaN
# 3825                         2.75                      NaN
# 3867                         2.59                      NaN
# 3906                         2.50                      NaN
# 4288                         1.99                      NaN
# 4309                         1.90                      NaN
# 5304                         4.29                      NaN
# 5342                         3.25                      NaN
# 5412                         4.29                      NaN
# 5421                         3.69                      NaN
# 5501                        13.58                      NaN
# 5560                         3.99                      NaN
# 5604                         5.99                      NaN
# 5800                         3.69                      NaN
# 6028                         5.19                      NaN
# 6212                         1.95                      NaN
# 6216                         1.69                      NaN
# 6231                         4.99                      NaN
# 6321                         1.29                      NaN
# 6324                         1.99                      NaN
# 6482                         7.99                      NaN
# 6494                         1.89                      NaN
# 6545                         3.99                      NaN
# 6563                         0.95                      NaN
# 6644                         0.65                      NaN
# 6737                         0.69                      NaN
# 6768                         1.05                      NaN
# 6793                         0.89                      NaN
# 6827                         0.75                      NaN
# 6833                         0.79                      NaN
# 6917                         2.40                      NaN
# 8040                         2.49                      NaN
#
#      product-fat-selector product-carb-selector   product-price-kilo-selector  \
# 21                    NaN                   NaN          Prijs per KG € 37,56
# 72                    NaN                   NaN          Prijs per KG € 55,80
# 78                    NaN                   NaN           Prijs per KG € 8,73
# 106                   NaN                   NaN  Normale prijs per KG € 11,33
# 256                   NaN                   NaN          Prijs per KG € 57,80
# 330                   NaN                   NaN           Prijs per KG € 2,98
# 372                   NaN                   NaN           Prijs per LT € 3,96
# 471                   NaN                   NaN           Prijs per KG € 2,00
# 492                   NaN                   NaN           Prijs per LT € 4,58
# 526                   NaN                   NaN           Prijs per KG € 3,49
# 1312                  NaN                   NaN          Prijs per KG € 17,96
# 1388                  NaN                   NaN          Prijs per KG € 18,48
# 1487                  NaN                   NaN          Prijs per KG € 19,96
# 1607                  NaN                   NaN          Prijs per KG € 14,95
# 1641                  NaN                   NaN          Prijs per KG € 18,71
# 1818                  NaN                   NaN          Prijs per KG € 27,90
# 2036                  NaN                   NaN          Prijs per KG € 15,03
# 2117                  NaN                   NaN          Prijs per KG € 11,09
# 2145                  NaN                   NaN  Normale prijs per KG € 11,09
# 2147                  NaN                   NaN  Normale prijs per KG € 11,09
# 2150                  NaN                   NaN  Normale prijs per KG € 15,20
# 2445                  NaN                   NaN  Normale prijs per KG € 14,87
# 2592                  NaN                   NaN           Prijs per KG € 7,95
# 2724                  NaN                   NaN  Normale prijs per LT € 11,92
# 2775                  NaN                   NaN           Prijs per KG € 7,95
# 2887                  NaN                   NaN          Prijs per LT € 17,24
# 3550                  NaN                   NaN          Prijs per KG € 28,99
# 3692                  NaN                   NaN          Prijs per KG € 27,18
# 3825                  NaN                   NaN          Prijs per KG € 27,50
# 3867                  NaN                   NaN          Prijs per KG € 21,58
# 3906                  NaN                   NaN          Prijs per KG € 25,00
# 4288                  NaN                   NaN          Prijs per KG € 18,09
# 4309                  NaN                   NaN          Prijs per KG € 17,29
# 5304                  NaN                   NaN          Prijs per KG € 17,16
# 5342                  NaN                   NaN           Prijs per LT € 9,03
# 5412                  NaN                   NaN          Prijs per KG € 17,16
# 5421                  NaN                   NaN          Prijs per KG € 14,76
# 5501                  NaN                   NaN           Prijs per KG € 8,49
# 5560                  NaN                   NaN          Prijs per KG € 15,96
# 5604                  NaN                   NaN          Prijs per KG € 13,31
# 5800                  NaN                   NaN          Prijs per KG € 14,76
# 6028                  NaN                   NaN          Prijs per KG € 10,38
# 6212                  NaN                   NaN          Prijs per KG € 32,50
# 6216                  NaN                   NaN          Prijs per KG € 16,90
# 6231                  NaN                   NaN         Prijs per KG € 142,57
# 6321                  NaN                   NaN          Prijs per LT € 33,95
# 6324                  NaN                   NaN         Prijs per KG € 124,38
# 6482                  NaN                   NaN         Prijs per LT € 133,17
# 6494                  NaN                   NaN          Prijs per KG € 78,75
# 6545                  NaN                   NaN         Prijs per LT € 114,00
# 6563                  NaN                   NaN          Prijs per KG € 38,00
# 6644                  NaN                   NaN          Prijs per KG € 27,08
# 6737                  NaN                   NaN          Prijs per KG € 32,86
# 6768                  NaN                   NaN          Prijs per LT € 27,63
# 6793                  NaN                   NaN          Prijs per KG € 11,13
# 6827                  NaN                   NaN          Prijs per KG € 35,71
# 6833                  NaN                   NaN           Prijs per KG € 9,88
# 6917                  NaN                   NaN           Prijs per KG € 6,67
# 8040                  NaN                   NaN          Prijs per KG € 11,37
#
#      product-protein-selector
# 21                        NaN
# 72                        NaN
# 78                        NaN
# 106                       NaN
# 256                       NaN
# 330                       NaN
# 372                       NaN
# 471                       NaN
# 492                       NaN
# 526                       NaN
# 1312                      NaN
# 1388                      NaN
# 1487                      NaN
# 1607                      NaN
# 1641                      NaN
# 1818                      NaN
# 2036                      NaN
# 2117                      NaN
# 2145                      NaN
# 2147                      NaN
# 2150                      NaN
# 2445                      NaN
# 2592                      NaN
# 2724                      NaN
# 2775                      NaN
# 2887                      NaN
# 3550                      NaN
# 3692                      NaN
# 3825                      NaN
# 3867                      NaN
# 3906                      NaN
# 4288                      NaN
# 4309                      NaN
# 5304                      NaN
# 5342                      NaN
# 5412                      NaN
# 5421                      NaN
# 5501                      NaN
# 5560                      NaN
# 5604                      NaN
# 5800                      NaN
# 6028                      NaN
# 6212                      NaN
# 6216                      NaN
# 6231                      NaN
# 6321                      NaN
# 6324                      NaN
# 6482                      NaN
# 6494                      NaN
# 6545                      NaN
# 6563                      NaN
# 6644                      NaN
# 6737                      NaN
# 6768                      NaN
# 6793                      NaN
# 6827                      NaN
# 6833                      NaN
# 6917                      NaN
# 8040                      NaN

# %% [markdown]
# The returned rows give several insights:
# * most of the products that have no protein also have no other nutritional data either
# * navigating to the page of the product, I find that it does mention protein content, but it is very small.
#
# ### Cleaning functions
#
# Now I will clean the data further and make it useable, primarily using regex functions on each column, starting with the kcal per 100g row.
# The easiest way to do this is to define a function, which I can subsequently apply on the column as a whole. I start by defining a function that finds text in the pattern of `(digits)+'Kcal')`, but only gives me the digits part.

# %%
def calorie_grabber(text):
    if type(text) != str:
        return None
    calories = re.findall(r'(\d+\.?\d+?) kcal', text)
    if len(calories) < 1:
        return None
    return float(calories[0])

# %% [markdown]
# Now the function is defined, I apply it to the original `product-calorie-selector` column and produce a new, clean column labeled `Kcal/100g`.

# %%
products['Kcal/100g'] = products['product-calorie-selector'].apply(calorie_grabber)
products
# Out:
#       web-scraper-order                              web-scraper-start-url  \
# 0          1665082128-1  https://www.ah.nl/producten/aardappel-groente-...
# 2          1665082133-3  https://www.ah.nl/producten/aardappel-groente-...
# 3          1665082136-4  https://www.ah.nl/producten/aardappel-groente-...
# 4          1665082139-5  https://www.ah.nl/producten/aardappel-groente-...
# 5          1665082142-6  https://www.ah.nl/producten/aardappel-groente-...
# ...                 ...                                                ...
# 9011     1665146006-100  https://www.ah.nl/producten/snoep-koek-chips-e...
# 9079     1665146168-168  https://www.ah.nl/producten/snoep-koek-chips-e...
# 9114     1665146252-203  https://www.ah.nl/producten/snoep-koek-chips-e...
# 9183     1665146424-272  https://www.ah.nl/producten/snoep-koek-chips-e...
# 10784   1665151306-1873  https://www.ah.nl/producten/snoep-koek-chips-e...
#
#                                        link-selector  \
# 0                             AH Primeur aardappelen
# 2                      AH Vegan zeewiersalade wakame
# 3      Appelsientje Proef! sinaasappel mango kurkuma
# 4                             AH Paddenstoelengehakt
# 5                    AH Lunchsalade couscous falafel
# ...                                              ...
# 9011                                Kinder Chocolade
# 9079       Xylifresh Peppermint gum sugarfree 4-pack
# 9114              Liga Belvita melk & granen koekjes
# 9183                                AH Pompoenpitten
# 10784                   AH Biologisch Pijnboompitten
#
#                                       link-selector-href  \
# 0      https://www.ah.nl/producten/product/wi96048/ah...
# 2      https://www.ah.nl/producten/product/wi523411/a...
# 3      https://www.ah.nl/producten/product/wi520760/a...
# 4      https://www.ah.nl/producten/product/wi515448/a...
# 5      https://www.ah.nl/producten/product/wi475648/a...
# ...                                                  ...
# 9011   https://www.ah.nl/producten/product/wi124148/k...
# 9079   https://www.ah.nl/producten/product/wi480890/x...
# 9114   https://www.ah.nl/producten/product/wi221045/l...
# 9183   https://www.ah.nl/producten/product/wi161495/a...
# 10784  https://www.ah.nl/producten/product/wi470173/a...
#
#        product-base-price-selector product-calorie-selector  \
# 0                             2.99         371 kJ (88 kcal)
# 2                             2.39        439 kJ (105 kcal)
# 3                             1.89         173 kJ (41 kcal)
# 4                             2.49         124 kJ (29 kcal)
# 5                             3.79        610 kJ (147 kcal)
# ...                            ...                      ...
# 9011                          2.49       2360 kJ (566 kcal)
# 9079                          2.65        753 kJ (181 kcal)
# 9114                          2.69       1828 kJ (435 kcal)
# 9183                          2.14       2558 kJ (617 kcal)
# 10784                         5.99       2935 kJ (710 kcal)
#
#       product-fat-selector product-carb-selector  \
# 0                   Vet0 g      Koolhydraten19 g
# 2                 Vet5.2 g      Koolhydraten11 g
# 3                   Vet0 g     Koolhydraten9.6 g
# 4                 Vet0.1 g     Koolhydraten4.3 g
# 5                 Vet9.6 g      Koolhydraten10 g
# ...                    ...                   ...
# 9011               Vet35 g    Koolhydraten53.5 g
# 9079              Vet0.9 g      Koolhydraten67 g
# 9114               Vet14 g      Koolhydraten66 g
# 9183               Vet49 g      Koolhydraten11 g
# 10784              Vet68 g       Koolhydraten6 g
#
#         product-price-kilo-selector product-protein-selector  Kcal/100g
# 0               Prijs per KG € 1,99              Eiwitten2 g       88.0
# 2              Prijs per KG € 23,90            Eiwitten1.5 g      105.0
# 3       Normale prijs per LT € 1,89            Eiwitten0.2 g       41.0
# 4               Prijs per KG € 8,30            Eiwitten2.5 g       29.0
# 5              Prijs per KG € 12,43            Eiwitten3.7 g      147.0
# ...                             ...                      ...        ...
# 9011           Prijs per KG € 12,45            Eiwitten8.7 g      566.0
# 9079           Prijs per KG € 36,81              Eiwitten0 g      181.0
# 9114            Prijs per KG € 8,97            Eiwitten7.8 g      435.0
# 9183   Normale prijs per KG € 28,50             Eiwitten30 g      617.0
# 10784          Prijs per KG € 59,90             Eiwitten15 g      710.0
#
# [5337 rows x 11 columns]

# %% [markdown]
# Seeing the function has succesfully been applied to this column, I can use the exact same principle to the other columns. I make some minor alterations to the function to allow the function to parse this particular format of text, but generally it can remain as it is.

# %%
def value_grabber(text):
    if type(text) != str:
        return None
    value1 = re.findall(r'(\d+\.?\d+?) g', text)
    if len(value1) < 1:
        return None
    return float(value1[0])

# %% [markdown]
# Having formulated the function to properly parse the text in these columns, I can apply it to all three columns individually and create the proper clean columns `fat/100g`, `carbs/100g`, `protein/100g`.

# %%
products['fat/100g'] = products['product-fat-selector'].apply(value_grabber)
products['carb/100g'] = products['product-carb-selector'].apply(value_grabber)
products['protein/100g'] = products['product-protein-selector'].apply(value_grabber)
products
# Out:
#       web-scraper-order                              web-scraper-start-url  \
# 0          1665082128-1  https://www.ah.nl/producten/aardappel-groente-...
# 2          1665082133-3  https://www.ah.nl/producten/aardappel-groente-...
# 3          1665082136-4  https://www.ah.nl/producten/aardappel-groente-...
# 4          1665082139-5  https://www.ah.nl/producten/aardappel-groente-...
# 5          1665082142-6  https://www.ah.nl/producten/aardappel-groente-...
# ...                 ...                                                ...
# 9011     1665146006-100  https://www.ah.nl/producten/snoep-koek-chips-e...
# 9079     1665146168-168  https://www.ah.nl/producten/snoep-koek-chips-e...
# 9114     1665146252-203  https://www.ah.nl/producten/snoep-koek-chips-e...
# 9183     1665146424-272  https://www.ah.nl/producten/snoep-koek-chips-e...
# 10784   1665151306-1873  https://www.ah.nl/producten/snoep-koek-chips-e...
#
#                                        link-selector  \
# 0                             AH Primeur aardappelen
# 2                      AH Vegan zeewiersalade wakame
# 3      Appelsientje Proef! sinaasappel mango kurkuma
# 4                             AH Paddenstoelengehakt
# 5                    AH Lunchsalade couscous falafel
# ...                                              ...
# 9011                                Kinder Chocolade
# 9079       Xylifresh Peppermint gum sugarfree 4-pack
# 9114              Liga Belvita melk & granen koekjes
# 9183                                AH Pompoenpitten
# 10784                   AH Biologisch Pijnboompitten
#
#                                       link-selector-href  \
# 0      https://www.ah.nl/producten/product/wi96048/ah...
# 2      https://www.ah.nl/producten/product/wi523411/a...
# 3      https://www.ah.nl/producten/product/wi520760/a...
# 4      https://www.ah.nl/producten/product/wi515448/a...
# 5      https://www.ah.nl/producten/product/wi475648/a...
# ...                                                  ...
# 9011   https://www.ah.nl/producten/product/wi124148/k...
# 9079   https://www.ah.nl/producten/product/wi480890/x...
# 9114   https://www.ah.nl/producten/product/wi221045/l...
# 9183   https://www.ah.nl/producten/product/wi161495/a...
# 10784  https://www.ah.nl/producten/product/wi470173/a...
#
#        product-base-price-selector product-calorie-selector  \
# 0                             2.99         371 kJ (88 kcal)
# 2                             2.39        439 kJ (105 kcal)
# 3                             1.89         173 kJ (41 kcal)
# 4                             2.49         124 kJ (29 kcal)
# 5                             3.79        610 kJ (147 kcal)
# ...                            ...                      ...
# 9011                          2.49       2360 kJ (566 kcal)
# 9079                          2.65        753 kJ (181 kcal)
# 9114                          2.69       1828 kJ (435 kcal)
# 9183                          2.14       2558 kJ (617 kcal)
# 10784                         5.99       2935 kJ (710 kcal)
#
#       product-fat-selector product-carb-selector  \
# 0                   Vet0 g      Koolhydraten19 g
# 2                 Vet5.2 g      Koolhydraten11 g
# 3                   Vet0 g     Koolhydraten9.6 g
# 4                 Vet0.1 g     Koolhydraten4.3 g
# 5                 Vet9.6 g      Koolhydraten10 g
# ...                    ...                   ...
# 9011               Vet35 g    Koolhydraten53.5 g
# 9079              Vet0.9 g      Koolhydraten67 g
# 9114               Vet14 g      Koolhydraten66 g
# 9183               Vet49 g      Koolhydraten11 g
# 10784              Vet68 g       Koolhydraten6 g
#
#         product-price-kilo-selector product-protein-selector  Kcal/100g  \
# 0               Prijs per KG € 1,99              Eiwitten2 g       88.0
# 2              Prijs per KG € 23,90            Eiwitten1.5 g      105.0
# 3       Normale prijs per LT € 1,89            Eiwitten0.2 g       41.0
# 4               Prijs per KG € 8,30            Eiwitten2.5 g       29.0
# 5              Prijs per KG € 12,43            Eiwitten3.7 g      147.0
# ...                             ...                      ...        ...
# 9011           Prijs per KG € 12,45            Eiwitten8.7 g      566.0
# 9079           Prijs per KG € 36,81              Eiwitten0 g      181.0
# 9114            Prijs per KG € 8,97            Eiwitten7.8 g      435.0
# 9183   Normale prijs per KG € 28,50             Eiwitten30 g      617.0
# 10784          Prijs per KG € 59,90             Eiwitten15 g      710.0
#
#        fat/100g  carb/100g  protein/100g
# 0           NaN       19.0           NaN
# 2           5.2       11.0           1.5
# 3           NaN        9.6           0.2
# 4           0.1        4.3           2.5
# 5           9.6       10.0           3.7
# ...         ...        ...           ...
# 9011       35.0       53.5           8.7
# 9079        0.9       67.0           NaN
# 9114       14.0       66.0           7.8
# 9183       49.0       11.0          30.0
# 10784      68.0        NaN          15.0
#
# [5337 rows x 14 columns]

# %% [markdown]
# I move on to clean `product-price-kilo-selector`. To do this, I'm going to have to replace the `,` with a `.`, and divide the total by 10 so I can immediately see the price per 100g/ml.

# %%
def price_in_100gram_grabber(text):
    if type(text) != str:
        return None
    cleanprice = text.replace(",",".")
    price = re.findall(r'K?G?L?T? € (\d+\.?\d+?)', cleanprice)
    if len(price) < 1:
        return None
    pricefloat = float(price[0]) 
    return pricefloat/10

# %% [markdown]
# Having defined the function to grab the price and clean it, we now apply it to the data.

# %%
products['€/100g or ml'] = products['product-price-kilo-selector'].apply(price_in_100gram_grabber)

# %% [markdown]
# ## Wrapping up
# As a final step, we define a clean, workable dataframe. Using this, we can start the analyses to get the info we want. For example, we figure out the ratio of protein to calories by adding column of protein/kcal.
# As a final touch, we rename a couple of columns to be a bit prettier.

# %%
products_clean = products[['link-selector','product-base-price-selector','Kcal/100g', 'fat/100g', 'carb/100g','protein/100g', '€/100g or ml']]
products_clean['protein/Kcal'] = products_clean['protein/100g']/products_clean['Kcal/100g']
products_clean.rename(columns={'link-selector':'product name', 'product-base-price-selector': 'base price'}, inplace= True)
# Out:
# C:\Users\Oamoh\AppData\Local\Temp\ipykernel_3424\1249344676.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_clean['protein/Kcal'] = products_clean['protein/100g']/products_clean['Kcal/100g']
# C:\Users\Oamoh\AppData\Local\Temp\ipykernel_3424\1249344676.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_clean.rename(columns={'link-selector':'product name', 'product-base-price-selector': 'base price'}, inplace= True)

# %% [markdown]
# This leaves us with a beautiful dataset, as shown below.

# %%
products_clean
# Out:
#                                         product name  base price  Kcal/100g  \
# 0                             AH Primeur aardappelen        2.99       88.0
# 2                      AH Vegan zeewiersalade wakame        2.39      105.0
# 3      Appelsientje Proef! sinaasappel mango kurkuma        1.89       41.0
# 4                             AH Paddenstoelengehakt        2.49       29.0
# 5                    AH Lunchsalade couscous falafel        3.79      147.0
# ...                                              ...         ...        ...
# 9011                                Kinder Chocolade        2.49      566.0
# 9079       Xylifresh Peppermint gum sugarfree 4-pack        2.65      181.0
# 9114              Liga Belvita melk & granen koekjes        2.69      435.0
# 9183                                AH Pompoenpitten        2.14      617.0
# 10784                   AH Biologisch Pijnboompitten        5.99      710.0
#
#        fat/100g  carb/100g  protein/100g  €/100g or ml  protein/Kcal
# 0           NaN       19.0           NaN          0.19           NaN
# 2           5.2       11.0           1.5          2.39      0.014286
# 3           NaN        9.6           0.2          0.18      0.004878
# 4           0.1        4.3           2.5          0.83      0.086207
# 5           9.6       10.0           3.7          1.24      0.025170
# ...         ...        ...           ...           ...           ...
# 9011       35.0       53.5           8.7          1.24      0.015371
# 9079        0.9       67.0           NaN          3.68           NaN
# 9114       14.0       66.0           7.8          0.89      0.017931
# 9183       49.0       11.0          30.0          2.85      0.048622
# 10784      68.0        NaN          15.0          5.99      0.021127
#
# [5337 rows x 8 columns]

# %% [markdown]
# ## exporting the dataset for analysis
#
# Here I choose to export the dataset as both a `.csv` as well as a `.xlsx` file for analysis. While `.csv` files are generally liked best for analysis with pandas, I have found `.xlsx` works more nicely with PowerBI.

# %%
products_clean.to_excel('products.xlsx')
products_clean.to_csv('products.csv')
